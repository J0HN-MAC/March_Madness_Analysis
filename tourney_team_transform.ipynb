# %%
import pandas as pd

# %%
# Read in CSV 
tourney_team_df = pd.read_csv('Resources/Tournament Team Data.csv')
tourney_team_df
# Out:
#       YEAR  SEED         TEAM  TEAM ROUND  CURRENT ROUND  \
# 0     2022     1      Gonzaga          16             64
# 1     2022    16  Georgia St.          64             64
# 2     2022     8    Boise St.          64             64
# 3     2022     9      Memphis          32             64
# 4     2022     5  Connecticut          64             64
# ...    ...   ...          ...         ...            ...
# 1903  2023     5     Miami FL           0              0
# 1904  2023     1      Houston           0              0
# 1905  2023     5      Rutgers           0              0
# 1906  2023     1    Tennessee           0              0
# 1907  2023     5  Connecticut           0              0
#
#       KENPOM ADJUSTED EFFICIENCY  KENPOM ADJUSTED OFFENSE  \
# 0                        33.0000                  121.800
# 1                         1.8000                  101.500
# 2                        16.4000                  108.400
# ...
