# %%
import pandas as pd

# %%
# Read in CSV 
tourney_team_df = pd.read_csv('Resources/Tournament Team Data.csv')
tourney_team_df.head(24)
# Out:
#     YEAR  SEED               TEAM  TEAM ROUND  CURRENT ROUND  \
# 0   2022     1            Gonzaga          16             64
# 1   2022    16        Georgia St.          64             64
# 2   2022     8          Boise St.          64             64
# 3   2022     9            Memphis          32             64
# 4   2022     5        Connecticut          64             64
# 5   2022    12     New Mexico St.          32             64
# 6   2022     4           Arkansas           8             64
# 7   2022    13            Vermont          64             64
# 8   2022     6            Alabama          64             64
# 9   2022    11         Notre Dame          32             64
# 10  2022     3         Texas Tech          16             64
# 11  2022    14        Montana St.          64             64
# 12  2022     7       Michigan St.          32             64
# 13  2022    10           Davidson          64             64
# ...
